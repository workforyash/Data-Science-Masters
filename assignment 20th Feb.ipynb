# %% [markdown]
# - Q1.
# - GET and POST methods both are used to get the data from client web page. However, GET method sends data in unencrypted form directly from URL while using POST method we can get the data from the form.

# %% [markdown]
# - Q2.
# - Data from client's web page is sent to server as a global request object. To process the data we use the request object from flask module

# %% [markdown]
# - Q3.
# - redirect() is used to redirecting to other routes on the same application.

# %% [markdown]
# - Q4.
# - To get rid of hard coding complete html content in the return statements we can use render_template() function to load complete web pages that are separately written in HTML files.

# %% [markdown]
# -Q5.

# %% [markdown]
# ![Screenshot%20%2810%29.png](attachment:Screenshot%20%2810%29.png)
