# %% [markdown]
# - Q1.
# flask is a micro web framework used to create web applications,
# advantages of flask is that it is more pythonic and easy to use

# %% [markdown]
# - Q2.
#
# ![Screenshot%20%282%29.png](attachment:Screenshot%20%282%29.png)

# %% [markdown]
# ![Screenshot%20%283%29.png](attachment:Screenshot%20%283%29.png)

# %% [markdown]
# Q3.

# %% [markdown]
# App routes convert the local fucntion to be accessed by a url, it is used to convert local functions to be accessed by urls

# %% [markdown]
# Q4.

# %% [markdown]
# ![Screenshot%20%287%29.png](attachment:Screenshot%20%287%29.png)

# %% [markdown]
# ![Screenshot%20%286%29.png](attachment:Screenshot%20%286%29.png)

# %% [markdown]
# ![Screenshot%20%284%29.png](attachment:Screenshot%20%284%29.png)

# %% [markdown]
# Q5.

# %% [markdown]
# To build a url specific function, url_for() is used. For eg.,
